# %%
pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/80/6f/57d36f6507e432d7fc1956b2e9e8530c5c2d2bfcd8821bcbfae271cd6688/tensorflow-2.14.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for tensorflow-intel==2.14.0 from https://files.pythonhosted.org/packages/ad/6e/1bfe367855dd87467564f7bf9fa14f3b17889988e79598bc37bf18f5ffb6/tensorflow_intel-2.14.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for flatbuffers>=23.5.26 from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
# ...

# %%
import tensorflow as tf
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from tensorflow.keras.datasets import mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 3s 0us/step

# %%
train_images = train_images.reshape(-1, 28*28)/255 # standardized
test_images = test_images.reshape(-1, 28*28)/255

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
## Building deep learning model

dl_model = tf.keras.Sequential(
    [tf.keras.layers.Flatten(input_shape=(28*28,)),
     tf.keras.layers.Dense(128, activation='relu'),
     tf.keras.layers.Dense(10, activation='softmax')
    ]
)

# %%
# compile the model
dl_model.compile(optimizer = 'adam',
                 loss='sparse_categorical_crossentropy',
                 metrics = ['accuracy'])

# %%
dl_model.fit(train_images, train_labels, epochs=5) # change epochs=10 to epochs=5 , then run next cell.
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0127 - accuracy: 0.9962
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0119 - accuracy: 0.9964
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0103 - accuracy: 0.9968
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0082 - accuracy: 0.9974

# %%
dl_test_loss, dl_test_acc = dl_model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0872 - accuracy: 0.9809

# %%
predictions = dl_model.predict(test_images)
# Out:
# 313/313 [==============================] - 2s 4ms/step

# %%
import numpy as np

# %%
predicted_classes = np.argmax(predictions, axis=1)

# %%
predicted_classes
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=int64)

# %%
accuracy_score(predicted_classes, test_labels)
# Out:
# 0.9809

# %%
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(train_images, train_labels)
rf_pred = rf_model.predict(test_images)
accuracy_score(rf_pred, test_labels)
# Out:
# 0.9682

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(train_images, train_labels)
lr_pred = lr_model.predict(test_images)
accuracy_score(lr_pred, test_labels)
# Out:
# 0.9256
