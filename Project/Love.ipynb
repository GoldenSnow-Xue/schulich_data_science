# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\Golden Snow\Desktop\Dataset for FA23 Analytics Quiz Regular.xlsx")

# %%
df.describe()
# Out:
#        customer_number                   date_of_sale    list_price  \
# count     51579.000000                          51579  51579.000000
# mean     491795.672134  2021-04-01 12:06:12.709823744     18.552167
# min          32.000000            2019-01-01 00:00:00      0.723674
# 25%      242411.000000            2020-03-17 00:00:00      5.210000
# 50%      480880.000000            2021-04-05 00:00:00      8.866505
# 75%      744763.000000            2022-03-14 00:00:00     15.541679
# max      999853.000000            2202-10-01 00:00:00    526.000000
# std      288158.377969                            NaN     32.279404
#
#                cost  quantity_sold  sales revenue  total cost  gross profit
# count  51579.000000   51579.000000            0.0         0.0           0.0
# mean      11.201456     530.895675            NaN         NaN           NaN
# min        0.770000       7.000000            NaN         NaN           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51579 entries, 0 to 51578
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_number  51579 non-null  int64
#  1   region           51579 non-null  object
#  2   date_of_sale     51579 non-null  datetime64[ns]
#  3   item             51579 non-null  object
#  4   brand            51579 non-null  object
#  5   collection       51579 non-null  object
#  6   description      51579 non-null  object
#  7   list_price       51579 non-null  float64
#  8   cost             51579 non-null  float64
#  9   quantity_sold    51579 non-null  int64
#  10  sales revenue    0 non-null      float64
#  11  total cost       0 non-null      float64
#  12  gross profit     0 non-null      float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 5.1+ MB

# %%
df.hist(figsize=(15,10))
plt.show()
